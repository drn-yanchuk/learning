# %% [markdown]
# # Momentum Strategy

# %% [markdown]
# ### Picking a stock universe - e.g. Dow Jones Industrial Average
#
# ### Performance evaluation: checking the performance over every single stock over the last 12 month
# ### skip the most recent month => buy winners & short losers

# %% [markdown]
# #### Highest quantile = winners
# #### lowest quintile = losers
#
# ##### Calculate the strategy return and compare return to the benchmark -> Dow Jones Performance

# %%
import yfinance as yf
import pandas_datareader.data as reader
import pandas as pd
import datetime as dt
from dateutil.relativedelta import relativedelta

# %%
# Get ticker symbols for the stocks contained in DJI

wiki_url = "https://en.wikipedia.org/wiki/Dow_Jones_Industrial_Average"
tables   = pd.read_html(wiki_url)

# find the table with “Symbol” & “Company”
for tbl in tables:
    if {"Symbol","Company"}.issubset(tbl.columns):
        dji_components = tbl
        break

table = dji_components
tickers = table.Symbol.tolist()
tickers
# Out:
# ['MMM',
#  'AXP',
#  'AMGN',
#  'AMZN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CVX',
#  'CSCO',
#  'KO',
#  'DIS',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'JNJ',
#  'JPM',
#  'MCD',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'NVDA',
#  'PG',
#  'CRM',
#  'SHW',
#  'TRV',
#  'UNH',
#  'VZ',
#  'V',
#  'WMT']

# %%
# Get prices for the DJI componets
start = dt.datetime(2018,1,31)
end = dt.datetime(2020,1,31)

df = yf.download(tickers, start, end, auto_adjust = False)['Adj Close']
df
# Out:
# [*********************100%***********************]  30 of 30 completed
# Ticker           AAPL        AMGN       AMZN         AXP          BA  \
# Date
# 2018-01-31  39.293301  148.054565  72.544502   89.722427  337.712067
# 2018-02-01  39.375439  147.664581  69.500000   90.264008  340.161255
# 2018-02-02  37.666935  148.818481  71.497498   87.267235  332.508820
# 2018-02-05  36.725849  139.062271  69.500000   83.051903  313.420319
# 2018-02-06  38.260681  140.574234  72.141998   85.010635  324.884796
# ...               ...         ...        ...         ...         ...
# 2020-01-24  76.963326  190.414429  93.082001  125.538094  321.139313
# 2020-01-27  74.700211  188.186050  91.417000  121.384766  314.727478
# 2020-01-28  76.813431  189.781357  92.662498  123.066521  314.687714
# 2020-01-29  78.421303  191.731186  92.900002  122.351082  320.115387
# 2020-01-30  78.307678  190.887115  93.533997  123.782005  321.387817
#
# Ticker             CAT         CRM       CSCO        CVX         DIS  ...  \
# Date                                                                  ...
# 2018-01-31  137.699844  112.920532  33.149426  90.738747  103.949203  ...
# 2018-02-01  137.243011  111.760689  33.277096  90.898003  105.690147  ...
# 2018-02-02  133.224884  109.817711  32.662628  85.838043  103.977890  ...
# 2018-02-05  127.802437  106.714905  30.946899  81.523727  100.151672  ...
# 2018-02-06  132.311264  108.618233  32.056137  84.824646  101.557808  ...
# ...                ...         ...        ...        ...         ...  ...
# 2020-01-24  125.143089  180.528122  41.298122  87.506561  137.783051  ...
# 2020-01-27  120.997787  179.140289  40.131470  86.364334  133.671600  ...
# 2020-01-28  121.898178  181.261688  40.385094  86.935448  136.101089  ...
0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2018-02-28 -0.014848 -0.090572 -0.035153 -0.072839 -0.044852 -0.008661
# 2018-03-31 -0.043017  0.009679 -0.023557  0.004199 -0.050634 -0.027005
# 2018-04-30 -0.028887 -0.079095 -0.062379 -0.052283  0.104673  0.060692
# 2018-05-31  0.122036  0.011474  0.033857 -0.023404  0.021616  0.031920
# 2018-06-30 -0.060629  0.066831  0.074674 -0.042360  0.019452  0.013234
# 2018-07-31  0.033601  0.045530  0.081360  0.063757  0.032119  0.032390
# 2018-08-31  0.146915  0.025593  0.035725  0.011219  0.060185  0.075843
# 2018-09-30  0.001211  0.003376 -0.000813 -0.008603 -0.005671  0.021785
# 2018-10-31 -0.249769  0.074896 -0.135630 -0.035310 -0.017629 -0.081551
# 2018-11-30 -0.224050  0.065742  0.080008  0.041877  0.080004  0.029847
# 2018-12-31 -0.183137 -0.027404 -0.072181 -0.075786 -0.114586 -0.068943
# 2019-01-31  0.076779  0.057800  0.071316  0.048351  0.084618  0.023268
# 2019-02-28  0.074219  0.021561  0.030357  0.058706 -0.103553  0.099019
# 2019-03-31  0.164009  0.055809 -0.005748  0.038056  0.024704  0.054483
# 2019-04-30  0.008020  0.030578  0.056000  0.048046 -0.057389  0.052756
# 2019-05-31 -0.250748 -0.033527 -0.075362  0.012661  0.037457 -0.017344
# 2019-06-30  0.212387  0.065494  0.092597  0.032819  0.013609  0.075745
# 2019-07-31  0.027340  0.083488  0.119466 -0.019396  0.020491  0.025641
# 2019-08-31 -0.006189  0.018553  0.028980  0.002319 -0.060279  0.017308
# 2019-09-30  0.039162  0.034517  0.043892  0.017229 -0.066902 -0.048723
# 2019-10-31  0.154823  0.007440  0.040828 -0.118569  0.162801  0.039824
# 2019-11-30  0.078997 -0.019677  0.020844  0.043186  0.107519  0.033317
# 2019-12-31  0.085633  0.023267  0.000703  0.007771  0.054455  0.018373
# 2020-01-31  0.044666  0.014398 -0.025088 -0.020080 -0.044220  0.108089
#
# Ticker            VZ       WMT
# Date
# 2018-01-31  0.000000  0.000000
# 2018-02-28 -0.117070 -0.155628
# 2018-03-31  0.001676 -0.005661
# 2018-04-30  0.044980 -0.005732
# 2018-05-31 -0.034042 -0.061045
# 2018-06-30  0.055381  0.037679
# 2018-07-31  0.038336  0.041798
# 2018-08-31  0.052866  0.080542
# 2018-09-30 -0.018025 -0.020342
# 2018-10-31  0.081150  0.067831
# 2018-11-30  0.056227 -0.026227
# 2018-12-31 -0.067662 -0.040877
# 2019-01-31 -0.010412  0.028771
# 2019-02-28  0.033781  0.032975
# 2019-03-31  0.038827 -0.009447
# 2019-04-30 -0.022844  0.054444
# 2019-05-31 -0.049659 -0.008373
# 2019-06-30  0.051150  0.089216
# 2019-07-31 -0.022374 -0.000996
# 2019-08-31  0.052289  0.040247
# 2019-09-30  0.037826  0.038684
# 2019-10-31  0.012247 -0.011965
# 2019-11-30 -0.003803  0.015606
# 2019-12-31  0.019256  0.002377
# 2020-01-31 -0.023164 -0.019017
#
# [25 rows x 30 columns]

# %%
#calculate the return s of the last 11 month
import numpy as np

past_11 = (mtl_ret+1).rolling(11).apply(np.prod) - 1
past_11
# Out:
# Ticker          AAPL      AMGN      AMZN       AXP        BA       CAT  \
# Date
# 2018-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-04-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-06-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-07-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-08-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-09-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-10-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-11-30  0.082608  0.152214  0.164919  0.141893 -0.002270 -0.151840
# 2018-12-31 -0.043731  0.077077  0.035206 -0.030504 -0.072073 -0.205605
# 2019-01-31 -0.055396  0.040230  0.136388  0.069161  0.080194 -0.118018
# 2019-02-28  0.047721  0.147929  0.132996  0.172494  0.368287 -0.045583
# 2019-03-31  0.166903  0.121022  0.137038  0.119381  0.166027 -0.043556
# 2019-04-30  0.086012  0.019969  0.182190  0.210360  0.088212 -0.059060
# 2019-05-31 -0.039841 -0.069399  0.044282  0.187968  0.039036 -0.094617
# 2019-06-30  0.055929 -0.033858  0.065369  0.254350  0.042565 -0.034231
# 2019-07-31 -0.053169 -0.044264 -0.072504  0.190477  0.010696 -0.026270
# 2019-08-31 -0.060959  0.037370 -0.113185  0.146671  0.000344 -0.198686
# 2019-09-30  0.039228  0.034606  0.086295  0.163800  0.095545  0.062291
# 2019-10-31  0.409686  0.048185  0.051172  0.059943 -0.002987  0.044490
# 2019-11-30  0.719699  0.242400  0.198959  0.278656  0.161603  0.171263
# 2019-12-31  0.790808  0.327567  0.075119  0.224934 -0.135766  0.133187
# 2020-01-31  0.890455  0.216537  0.140777  0.253845 -0.251987  0.014180
#
# Ticker           CRM      CSCO       CVX       DIS  ...      MSFT       NKE  \
# Date                                                ...
# 2018-01-31       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-02-28       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-03-31       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-04-30       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-05-31       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-06-30       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-07-31       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-08-31       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-09-30       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-10-31       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2018-11-30  0.253270  0.178616 -0.014529  0.071302  ...  0.187345  0.113583
# 2018-12-31  0.202441  0.066836 -0.098626  0.025019  ...  0.087552  0.099055
# 2019-01-31  0.307269  0.088455  0.053428  0.098182  ...  0.127664  0.235342
# 2019-02-28  0.407137  0.244077  0.089140  0.141272  ...  0.248175  0.300978
# 2019-03-31  0.308951  0.246395  0.022658  0.124197  ...  0.282407  0.244669
# 2019-04-30  0.278512  0.347905 -0.005422  0.398834  ...  0.337832  0.236521
# 2019-05-31  0.110044  0.244146 -0.063632  0.279781  ...  0.274601 -0.021392
# 2019-06-30  0.106307  0.321310  0.024763  0.239197  ...  0.283327  0.103358
# 2019-07-31  0.011920  0.191527  0.070388  0.294517  ...  0.228095  0.055330
# 2019-08-31 -0.018613 -0.011436  0.001743  0.190194  ...  0.224327  0.008327
# 2019-09-30  0.081609  0.102165  0.105318  0.150781  ...  0.322111  0.265307
# 2019-10-31  0.096175  0.020520  0.006217  0.140692  ...  0.307570  0.201582
# 2019-11-30  0.189238  0.075240  0.120405  0.390960  ...  0.512438  0.274347
# 2019-12-31  0.070211  0.034809  0.093818  0.312747  ...  0.532431  0.250402
# 2020-01-31  0.134556 -0.062086 -0.040204  0.236212  ...  0.558414  0.157470
#
# Ticker          NVDA        PG       SHW       TRV       UNH         V  \
# Date
# 2018-01-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-02-28       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-03-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-04-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-05-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-06-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-07-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-08-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-09-30       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-10-31       NaN       NaN       NaN       NaN       NaN       NaN
# 2018-11-30 -0.333254  0.124632  0.025318 -0.115475  0.204300  0.148307
# 2018-12-31 -0.455360  0.093812 -0.048690 -0.182509  0.066304  0.069139
# 2019-01-31 -0.404704  0.272267  0.056284 -0.075655  0.210841  0.103574
# 2019-02-28 -0.331777  0.287238  0.114606 -0.025482  0.143347  0.246510
# 2019-03-31 -0.199046  0.475807  0.181928  0.067411  0.060579  0.239213
# 2019-04-30 -0.280435  0.503681  0.207242  0.145505 -0.021440  0.264235
# 2019-05-31 -0.426068  0.362229  0.038698  0.211319 -0.004157  0.226082
# 2019-06-30 -0.326792  0.388241  0.049492  0.176090 -0.022016  0.277571
# 2019-07-31 -0.396979  0.466607  0.134346  0.140484 -0.058633  0.217956
# 2019-08-31 -0.401436  0.488791  0.168168  0.153049 -0.110332  0.212620
# 2019-09-30 -0.170916  0.432864  0.410785  0.215847 -0.154956  0.255963
# 2019-10-31  0.233900  0.354478  0.359605  0.028610 -0.090172  0.268131
# 2019-11-30  0.629861  0.365239  0.495922  0.161021  0.138058  0.407412
# 2019-12-31  0.643262  0.320670  0.397323  0.116080  0.106409  0.400680
# 2020-01-31  0.598055  0.311409  0.322131  0.033024  0.179638  0.412239
#
# Ticker            VZ       WMT
# Date
# 2018-01-31       NaN       NaN
# 2018-02-28       NaN       NaN
# 2018-03-31       NaN       NaN
# 2018-04-30       NaN       NaN
# 2018-05-31       NaN       NaN
# 2018-06-30       NaN       NaN
# 2018-07-31       NaN       NaN
# 2018-08-31       NaN       NaN
# 2018-09-30       NaN       NaN
# 2018-10-31       NaN       NaN
# 2018-11-30  0.155004 -0.067306
# 2018-12-31  0.076854 -0.105432
# 2019-01-31  0.206939  0.089929
# 2019-02-28  0.245624  0.132280
# 2019-03-31  0.238289  0.128049
# 2019-04-30  0.252644  0.266796
# 2019-05-31  0.127971  0.210576
# 2019-06-30  0.141891  0.265675
# 2019-07-31  0.060289  0.170167
# 2019-08-31  0.136210  0.242539
# 2019-09-30  0.090680  0.208623
# 2019-10-31  0.045265  0.226324
# 2019-11-30  0.116858  0.298544
# 2019-12-31  0.150342  0.265228
# 2020-01-31  0.086976  0.201546
#
# [25 rows x 30 columns]

# %%
# define formation day
formation = dt.datetime(2019,12,31)

end_measurement = formation - relativedelta(month=1)

# %%
formation
# Out:
# datetime.datetime(2019, 12, 31, 0, 0)

# %%
end_measurement
# Out:
# datetime.datetime(2019, 1, 31, 0, 0)

# %%
#loc functiom to find the end_measurement in that dataframe 
ret_12 = past_11.loc[end_measurement]
ret_12
# Out:
# Ticker
# AAPL   -0.055396
# AMGN    0.040230
# AMZN    0.136388
# AXP     0.069161
# BA      0.080194
# CAT    -0.118018
# CRM     0.307269
# CSCO    0.088455
# CVX     0.053428
# DIS     0.098182
# GS     -0.238673
# HD      0.029667
# HON     0.007208
# IBM    -0.107167
# JNJ     0.045734
# JPM    -0.080711
# KO      0.152121
# MCD     0.154781
# MMM    -0.132062
# MRK     0.414817
# MSFT    0.127664
# NKE     0.235342
# NVDA   -0.404704
# PG      0.272267
# SHW     0.056284
# TRV    -0.075655
# UNH     0.210841
# V       0.103574
# VZ      0.206939
# WMT     0.089929
# Name: 2019-01-31 00:00:00, dtype: float64

# %%
#transform series into dataframe 
ret_12 = ret_12.reset_index()
ret_12
# Out:
#    Ticker  2019-01-31 00:00:00
# 0    AAPL            -0.055396
# 1    AMGN             0.040230
# 2    AMZN             0.136388
# 3     AXP             0.069161
# 4      BA             0.080194
# 5     CAT            -0.118018
# 6     CRM             0.307269
# 7    CSCO             0.088455
# 8     CVX             0.053428
# 9     DIS             0.098182
# 10     GS            -0.238673
# 11     HD             0.029667
# 12    HON             0.007208
# 13    IBM            -0.107167
# 14    JNJ             0.045734
# 15    JPM            -0.080711
# 16     KO             0.152121
# 17    MCD             0.154781
# 18    MMM            -0.132062
# 19    MRK             0.414817
# 20   MSFT             0.127664
# 21    NKE             0.235342
# 22   NVDA            -0.404704
# 23     PG             0.272267
# 24    SHW             0.056284
# 25    TRV            -0.075655
# 26    UNH             0.210841
# 27      V             0.103574
# 28     VZ             0.206939
# 29    WMT             0.089929

# %%
# use quintiles to divide the distribution into 5 equal parts to see the winners [4} and losers [0]
# 1) coerce your returns columns to numeric (so numpy.isnan will work)
ret_12.iloc[:,1:] = ret_12.iloc[:,1:].apply(pd.to_numeric, errors='coerce')

# %%
# 2a) If you just want **one** quintile column based on a single return series (say the 2nd column):
ret_12['quintile'] = pd.qcut(
    ret_12.iloc[:,1],  # ← note: a Series, not a DataFrame
    5,
    labels=False
)
ret_12
# Out:
#    Ticker  2019-01-31 00:00:00  quintile
# 0    AAPL            -0.055396         1
# 1    AMGN             0.040230         1
# 2    AMZN             0.136388         3
# 3     AXP             0.069161         2
# 4      BA             0.080194         2
# 5     CAT            -0.118018         0
# 6     CRM             0.307269         4
# 7    CSCO             0.088455         2
# 8     CVX             0.053428         2
# 9     DIS             0.098182         3
# 10     GS            -0.238673         0
# 11     HD             0.029667         1
# 12    HON             0.007208         1
# 13    IBM            -0.107167         0
# 14    JNJ             0.045734         1
# 15    JPM            -0.080711         0
# 16     KO             0.152121         3
# 17    MCD             0.154781         3
# 18    MMM            -0.132062         0
# 19    MRK             0.414817         4
# 20   MSFT             0.127664         3
# 21    NKE             0.235342         4
# 22   NVDA            -0.404704         0
# 23     PG             0.272267         4
# 24    SHW             0.056284         2
# 25    TRV            -0.075655         1
# 26    UNH             0.210841         4
# 27      V             0.103574         3
# 28     VZ             0.206939         4
# 29    WMT             0.089929         2

# %%
winners = ret_12[ret_12.quintile == 4]
losers = ret_12[ret_12.quintile == 0]

# %%
winners
# Out:
#    Ticker  2019-01-31 00:00:00  quintile
# 6     CRM             0.307269         4
# 19    MRK             0.414817         4
# 21    NKE             0.235342         4
# 23     PG             0.272267         4
# 26    UNH             0.210841         4
# 28     VZ             0.206939         4

# %%
losers
# Out:
#    Ticker  2019-01-31 00:00:00  quintile
# 5     CAT            -0.118018         0
# 10     GS            -0.238673         0
# 13    IBM            -0.107167         0
# 15    JPM            -0.080711         0
# 18    MMM            -0.132062         0
# 22   NVDA            -0.404704         0

# %%
winner_ret = mtl_ret.loc[formation + relativedelta(month=1), df.columns.isin(winners.Ticker)]
loser_ret = mtl_ret.loc[formation + relativedelta(month=1), df.columns.isin(losers.Ticker)]

# %%
winner_ret
# Out:
# Ticker
# CRM    0.109513
# MRK   -0.025913
# NKE    0.104397
# PG     0.057800
# UNH    0.084618
# VZ    -0.010412
# Name: 2019-01-31 00:00:00, dtype: float64

# %%
loser_ret
# Out:
# Ticker
# CAT     0.054668
# GS      0.185333
# IBM     0.182546
# JPM     0.068844
# MMM     0.051223
# NVDA    0.076779
# Name: 2019-01-31 00:00:00, dtype: float64

# %%
#equal weighting the portfolio
momentum = winner_ret.mean() - loser_ret.mean()

# %%
momentum
# Out:
# -0.04989807332815863

# %%
#check how DJI performed in Jan to compare
DJI = yf.download('^DJI', start, end, auto_adjust = False)['Adj Close'].pct_change().resample('M').agg(lambda x: (x+1).prod() -1 )
DJI
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker          ^DJI
# Date
# 2018-01-31  0.000000
# 2018-02-28 -0.042838
# 2018-03-31 -0.037000
# 2018-04-30  0.002491
# 2018-05-31  0.010458
# 2018-06-30 -0.005915
# 2018-07-31  0.047125
# 2018-08-31  0.021626
# 2018-09-30  0.019006
# 2018-10-31 -0.050742
# 2018-11-30  0.016830
# 2018-12-31 -0.086575
# 2019-01-31  0.071684
# 2019-02-28  0.036654
# 2019-03-31  0.000489
# 2019-04-30  0.025618
# 2019-05-31 -0.066855
# 2019-06-30  0.071929
# 2019-07-31  0.009936
# 2019-08-31 -0.017160
# 2019-09-30  0.019450
# 2019-10-31  0.004807
# 2019-11-30  0.037165
# 2019-12-31  0.017362
# 2020-01-31  0.011248

# %% [markdown]
# ### One month after formation (i.e. in February 2019), you pulled each group’s month‑end return:
#
# ### Winners’ Feb‑2019 returns:
# ### CRM +10.95%, MRK −2.59%, NKE +10.44%, PG +5.78%, UNH +8.46%, VZ −1.04%
#
# ### Losers’ Feb‑2019 returns:
# ### CAT +5.47%, GS +18.53%, IBM +18.25%, JPM +6.88%, MMM +5.12%, NVDA +7.68%
#
# ## losing about -4.9% per month
# ## benchmark - + 3.66% per month
#
# ### Negative strategy return (–4.99%) means that in this single formation → holding window the “classic” momentum signal failed: the bottom‐past‑11‑month group actually outperformed the top group.
#
# ### DJIA benchmark (+3.67%) was positive—so a simple “buy index” would have beaten your long‑winners/short‑losers trade by ~8.7 percentage points that month.
